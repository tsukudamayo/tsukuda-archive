# %%
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Firefox()

# %%
for mon in range(1,13):
    url = "http://www.data.jma.go.jp/obd/stats/etrn/view/daily_s1.php?prec_no=14&block_no=47412&year=2015&month="+str(i)+"&day=&view="
    driver.get(url)
    df = pd.io.html.read_html(url)
    print(df[0])
    data = df[0]
    data.to_csv("kisyou_kako_data_pandas"+str(i)+".csv")
# Out:
#      0        1        2      3      4           5        6      7     8   \
# 0     日  気圧(hPa)  降水量(mm)  気温(℃)  湿度(％)  風向・風速(m/s)  日照時間(h)  雪(cm)  天気概況
# 1    現地       海面      NaN    NaN    NaN         NaN      NaN    NaN   NaN
# 2    平均       平均       合計     最大     平均          最高       最低     平均    最小
# 3   1時間     10分間       風速     風向     風速          風向       合計      値   NaN
# 4     1   1017.8   1021.1    8.5    3.5         1.0      0.7    2.4  -0.9
# 5     2   1019.5   1022.8     --     --          --      2.1    4.7  -1.9
# 6     3    997.7   1000.9    6.5    2.0         1.0      7.0   10.7   2.8
# 7     4    989.4    992.6    1.5    0.5         0.5      0.9    4.1  -2.5
# 8     5   1000.5   1003.8    3.0    1.5         0.5     -0.5    1.0  -1.9
# 9     6   1014.2   1017.6    0.5    0.5         0.5     -0.9    2.1  -3.5
# 10    7   1021.4   1024.7   10.0    4.5         1.5      1.3    4.7  -2.0
# 11    8   1024.6   1028.0     --     --          --      1.3    5.3  -1.8
# ...

# %%
#スクレイピングの開始
driver = webdriver.Firefox()

for year in range(2000,2017):
    for month in range(1,13):
        #url = "http://www.data.jma.go.jp/obd/stats/etrn/view/daily_s1.php?prec_no=14&block_no=47412&year="+str(year)+"&month="+str(month)+"&day=&view="
        url = "http://www.data.jma.go.jp/obd/stats/etrn/view/daily_s1.php?"+str(argv)+"&year="+str(year)+"&month="+str(month)+"&day=&view="
        driver.get(url)
        df = pd.io.html.read_html(url)
        print(df[0])
        data = df[0]
        #日付順にファイルが作成されなかったため以下の1行をコメントアウト
        #data.to_csv("kisyou_kako_data_"+str(year)+"_"+str(month)+".csv")
        data.to_csv(datetime.date(year,month,1).strftime('%Y-%m-%d') +".csv")

# %%
#テスト
#s = 3

# %%
#テスト
#for mon in range(1,13):
#    url = 'http://www.data.jma.go.jp/obd/stats/etrn/view/daily_s1.php?prec_no=14&block_no=47412&year=2016&month=1&day=&view='"""

# %%
#    driver.get(url)

# %%
#    df = pd.io.html.read_html(url)

# %%
#    print(df[0])
# Out:
#      0        1        2      3      4           5        6      7      8   \
# 0     日  気圧(hPa)  降水量(mm)  気温(℃)  湿度(％)  風向・風速(m/s)  日照時間(h)  雪(cm)   天気概況
# 1    現地       海面      NaN    NaN    NaN         NaN      NaN    NaN    NaN
# 2    平均       平均       合計     最大     平均          最高       最低     平均     最小
# 3   1時間     10分間       風速     風向     風速          風向       合計      値    NaN
# 4     1   1017.8   1021.2    1.0    1.0         0.5     -1.1    0.2   -2.6
# 5     2   1008.9   1012.2    3.5    1.0         1.0      1.6    4.0   -0.7
# 6     3   1009.9   1013.2    0.0    0.0         0.0      0.3    2.2   -1.8
# 7     4   1009.1   1012.4    0.0    0.0         0.0     -1.7   -0.2   -3.8
# 8     5   1010.5   1013.9    0.5    0.5         0.5     -3.9   -2.4   -5.4
# 9     6   1010.0   1013.3    1.5    1.0         0.5     -2.3   -0.4   -4.0
# 10    7   1005.9   1009.2    0.0    0.0         0.0     -2.7   -1.2   -3.5
# ...

# %%
#    url = 'http://www.data.jma.go.jp/obd/stats/etrn/view/daily_s1.php?prec_no=14&block_no=47412&year=2016&month=2&day=&view='

# %%
#    driver.get(url)

# %%
#    df = pd.io.html.read_html(url)

# %%
#    print(df[0])
# Out:
#      0        1        2      3      4           5        6      7      8   \
# 0     日  気圧(hPa)  降水量(mm)  気温(℃)  湿度(％)  風向・風速(m/s)  日照時間(h)  雪(cm)   天気概況
# 1    現地       海面      NaN    NaN    NaN         NaN      NaN    NaN    NaN
# 2    平均       平均       合計     最大     平均          最高       最低     平均     最小
# 3   1時間     10分間       風速     風向     風速          風向       合計      値    NaN
# 4     1   1015.6   1019.0     --     --          --     -5.5   -2.9   -7.4
# 5     2   1011.9   1015.2    3.0    1.5         1.0     -4.5   -1.2   -6.4
# 6     3   1016.1   1019.4    3.0    1.5         1.0     -3.5   -0.4   -7.6
# 7     4   1011.3   1014.6    0.0    0.0         0.0     -0.4    2.5   -4.0
# 8     5   1009.1   1012.4    0.5    0.5         0.5     -2.4   -0.3   -5.5
# 9     6   1009.7   1013.1    0.0    0.0         0.0     -4.9   -1.9   -7.6
# 10    7   1009.6   1012.9    2.5    1.0         0.5     -4.7   -1.7   -8.5
# ...

# %%
#    url = 'http://www.data.jma.go.jp/obd/stats/etrn/view/daily_s1.php?prec_no=14&block_no=47412&year=2016&month="+str(i)+"&day=&view='

# %%
#    driver.get(url)

# %%
#    df = pd.io.html.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-127-3d9e8b455c44> in <module>()
# ----> 1 df = pd.io.html.read_html(url)
#
# /Users/tsukudamayo/.pyenv/versions/3.5.0/lib/python3.5/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     864     _validate_header_arg(header)
#     865     return _parse(flavor, io, match, header, index_col, skiprows,
# --> 866                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# /Users/tsukudamayo/.pyenv/versions/3.5.0/lib/python3.5/site-packages/pandas/io/html.py in _parse(flavor, io, match, header, index_col, skiprows, parse_dates, tupleize_cols, thousands, attrs, encoding)
#     726             break
#     727     else:
# --> 728         raise_with_traceback(retained)
#     729
#     730     ret = []
#
# ...

# %%
#    print(df[0])
# Out:
#      0        1        2      3      4           5        6      7      8   \
# 0     日  気圧(hPa)  降水量(mm)  気温(℃)  湿度(％)  風向・風速(m/s)  日照時間(h)  雪(cm)   天気概況
# 1    現地       海面      NaN    NaN    NaN         NaN      NaN    NaN    NaN
# 2    平均       平均       合計     最大     平均          最高       最低     平均     最小
# 3   1時間     10分間       風速     風向     風速          風向       合計      値    NaN
# 4     1   1015.6   1019.0     --     --          --     -5.5   -2.9   -7.4
# 5     2   1011.9   1015.2    3.0    1.5         1.0     -4.5   -1.2   -6.4
# 6     3   1016.1   1019.4    3.0    1.5         1.0     -3.5   -0.4   -7.6
# 7     4   1011.3   1014.6    0.0    0.0         0.0     -0.4    2.5   -4.0
# 8     5   1009.1   1012.4    0.5    0.5         0.5     -2.4   -0.3   -5.5
# 9     6   1009.7   1013.1    0.0    0.0         0.0     -4.9   -1.9   -7.6
# 10    7   1009.6   1012.9    2.5    1.0         0.5     -4.7   -1.7   -8.5
# ...

# %%
#ループテスト
for i in range(1,13):
    print("xは"+str(i)+"です")
# Out:
# xは1です
# xは2です
# xは3です
# xは4です
# xは5です
# xは6です
# xは7です
# xは8です
# xは9です
# xは10です
# xは11です
# xは12です

# %%
#ループテスト
for i in range(1,13):
    url = "http = "+str(i)+""
    print(url)
# Out:
# http = 1
# http = 2
# http = 3
# http = 4
# http = 5
# http = 6
# http = 7
# http = 8
# http = 9
# http = 10
# http = 11
# http = 12

# %%
#ループテスト
for i in range(1,13):
    url = 'http = "+str(i)+"'
    print(url)
# Out:
# http = "+str(i)+"
# http = "+str(i)+"
# http = "+str(i)+"
# http = "+str(i)+"
# http = "+str(i)+"
# http = "+str(i)+"
# http = "+str(i)+"
# http = "+str(i)+"
# http = "+str(i)+"
# http = "+str(i)+"
# http = "+str(i)+"
# http = "+str(i)+"

# %%
#ループテスト
for y in range(2000,2017):
    for i in range(1,13):
        url ="http = "+str(y)+","+str(i)+""
        print(url)
# Out:
# http = 2000,1
# http = 2000,2
# http = 2000,3
# http = 2000,4
# http = 2000,5
# http = 2000,6
# http = 2000,7
# http = 2000,8
# http = 2000,9
# http = 2000,10
# http = 2000,11
# http = 2000,12
# http = 2001,1
# http = 2001,2
# http = 2001,3
# http = 2001,4
# http = 2001,5
# http = 2001,6
# http = 2001,7
# http = 2001,8
# http = 2001,9
# http = 2001,10
# http = 2001,11
# http = 2001,12
# http = 2002,1
# http = 2002,2
# http = 2002,3
# http = 2002,4
# http = 2002,5
# http = 2002,6
# http = 2002,7
# http = 2002,8
# http = 2002,9
# http = 2002,10
# http = 2002,11
# http = 2002,12
# http = 2003,1
# http = 2003,2
# http = 2003,3
# http = 2003,4
# http = 2003,5
# http = 2003,6
# http = 2003,7
# http = 2003,8
# http = 2003,9
# http = 2003,10
# http = 2003,11
# http = 2003,12
# http = 2004,1
# http = 2004,2
# http = 2004,3
# http = 2004,4
# http = 2004,5
# http = 2004,6
# http = 2004,7
# http = 2004,8
# http = 2004,9
# http = 2004,10
# http = 2004,11
# http = 2004,12
# http = 2005,1
# ...

# %%
#日付のテスト
from datetime import date
ganjitsu = date(2015,1,1)
print(ganjitsu)
for year in range(2000,2017):
    for month in range(1,13):
        fname = date(year,month,1)
        print(fname)
# Out:
# 2015-01-01
# 2000-01-01
# 2000-02-01
# 2000-03-01
# 2000-04-01
# 2000-05-01
# 2000-06-01
# 2000-07-01
# 2000-08-01
# 2000-09-01
# 2000-10-01
# 2000-11-01
# 2000-12-01
# 2001-01-01
# 2001-02-01
# 2001-03-01
# 2001-04-01
# 2001-05-01
# 2001-06-01
# 2001-07-01
# 2001-08-01
# 2001-09-01
# 2001-10-01
# 2001-11-01
# 2001-12-01
# 2002-01-01
# 2002-02-01
# 2002-03-01
# 2002-04-01
# 2002-05-01
# 2002-06-01
# 2002-07-01
# 2002-08-01
# 2002-09-01
# 2002-10-01
# 2002-11-01
# 2002-12-01
# 2003-01-01
# 2003-02-01
# 2003-03-01
# 2003-04-01
# 2003-05-01
# 2003-06-01
# 2003-07-01
# 2003-08-01
# 2003-09-01
# 2003-10-01
# 2003-11-01
# 2003-12-01
# 2004-01-01
# 2004-02-01
# 2004-03-01
# 2004-04-01
# 2004-05-01
# 2004-06-01
# 2004-07-01
# 2004-08-01
# 2004-09-01
# 2004-10-01
# 2004-11-01
# 2004-12-01
# 2005-01-01
# 2005-02-01
# 2005-03-01
# 2005-04-01
# 2005-05-01
# 2005-06-01
# 2005-07-01
# 2005-08-01
# 2005-09-01
# 2005-10-01
# 2005-11-01
# 2005-12-01
# 2006-01-01
# 2006-02-01
# 2006-03-01
# ...

# %%
#コマンドラインオプションテスト
import argparse
sapporo   =    'prec_no=14&block_no=47412' 
parser = argparse.ArgumentParser(description='2000-2016 Weather data get from web')
parser.add_argument('sapporo',type=str, help='get data at sapporo')
args = parser.parse_args()
print(args)
# Out:
# usage: __main__.py [-h] sapporo
# __main__.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# To exit: use 'exit', 'quit', or Ctrl-D.

# %%
#import csv

# %%
for mon in range(1,13):
    url = "http://www.data.jma.go.jp/obd/stats/etrn/view/daily_s1.php?prec_no=14&block_no=47412&year=2015&month="+str(i)+"&day=&view="

# %%
    driver.get(url)

# %%
    df = pd.io.html.read_html(url)

# %%
    print(df[0])
# Out:
#      0        1        2      3      4           5        6      7     8   \
# 0     日  気圧(hPa)  降水量(mm)  気温(℃)  湿度(％)  風向・風速(m/s)  日照時間(h)  雪(cm)  天気概況
# 1    現地       海面      NaN    NaN    NaN         NaN      NaN    NaN   NaN
# 2    平均       平均       合計     最大     平均          最高       最低     平均    最小
# 3   1時間     10分間       風速     風向     風速          風向       合計      値   NaN
# 4     1   1017.8   1021.1    8.5    3.5         1.0      0.7    2.4  -0.9
# 5     2   1019.5   1022.8     --     --          --      2.1    4.7  -1.9
# 6     3    997.7   1000.9    6.5    2.0         1.0      7.0   10.7   2.8
# 7     4    989.4    992.6    1.5    0.5         0.5      0.9    4.1  -2.5
# 8     5   1000.5   1003.8    3.0    1.5         0.5     -0.5    1.0  -1.9
# 9     6   1014.2   1017.6    0.5    0.5         0.5     -0.9    2.1  -3.5
# 10    7   1021.4   1024.7   10.0    4.5         1.5      1.3    4.7  -2.0
# 11    8   1024.6   1028.0     --     --          --      1.3    5.3  -1.8
# ...

# %%
data = df[0]

# %%
data.to_csv("kisyou_kako_data_pandas"+str(i)+".csv")

# %%
#data = df[0]

# %%
#f = open("kisyou_kako_data_sample_"+str(i)+".csv", 'w')
#writer = csv.writer(f)
#writer.writerows(data)
#f.close()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-198-5c52ce91ae0b> in <module>()
#       1 f = open("kisyou_kako_data_sample_"+str(i)+".csv", 'w')
#       2 writer = csv.writer(f)
# ----> 3 writer.writerows(data)
#       4 f.close()
#
# Error: iterable expected, not numpy.int64

# %%
#テスト
#import csv

# %%
#テスト
#data = df{0}

# %%
#テスト
#f = open("kisyou_kako_data_sample_"+str(i)+"", 'w')
#writer = csv.writer(f)
#writer = writerow(data)
#f.close()
